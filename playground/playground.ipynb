# %%
import Quartz

# %%
vk_by_quartz_name = {
    "kVK_ANSI_A": 0x00,
    "kVK_ANSI_S": 0x01,
    "kVK_ANSI_D": 0x02,
    "kVK_ANSI_F": 0x03,
    "kVK_ANSI_H": 0x04,
    "kVK_ANSI_G": 0x05,
    "kVK_ANSI_Z": 0x06,
    "kVK_ANSI_X": 0x07,
    "kVK_ANSI_C": 0x08,
    "kVK_ANSI_V": 0x09,
    "kVK_ANSI_B": 0x0B,
    "kVK_ANSI_Q": 0x0C,
    "kVK_ANSI_W": 0x0D,
    "kVK_ANSI_E": 0x0E,
    "kVK_ANSI_R": 0x0F,
    "kVK_ANSI_Y": 0x10,
    "kVK_ANSI_T": 0x11,
    "kVK_ANSI_1": 0x12,
    "kVK_ANSI_2": 0x13,
    "kVK_ANSI_3": 0x14,
    "kVK_ANSI_4": 0x15,
    "kVK_ANSI_6": 0x16,
    "kVK_ANSI_5": 0x17,
    "kVK_ANSI_Equal": 0x18,
    "kVK_ANSI_9": 0x19,
    "kVK_ANSI_7": 0x1A,
    "kVK_ANSI_Minus": 0x1B,
    "kVK_ANSI_8": 0x1C,
    "kVK_ANSI_0": 0x1D,
    "kVK_ANSI_RightBracket": 0x1E,
    "kVK_ANSI_O": 0x1F,
    "kVK_ANSI_U": 0x20,
    "kVK_ANSI_LeftBracket": 0x21,
    "kVK_ANSI_I": 0x22,
    "kVK_ANSI_P": 0x23,
    "kVK_ANSI_L": 0x25,
    "kVK_ANSI_J": 0x26,
    "kVK_ANSI_Quote": 0x27,
    "kVK_ANSI_K": 0x28,
    "kVK_ANSI_Semicolon": 0x29,
    "kVK_ANSI_Backslash": 0x2A,
    "kVK_ANSI_Comma": 0x2B,
    "kVK_ANSI_Slash": 0x2C,
    "kVK_ANSI_N": 0x2D,
    "kVK_ANSI_M": 0x2E,
    "kVK_ANSI_Period": 0x2F,
    "kVK_ANSI_Grave": 0x32,
    "kVK_ANSI_KeypadDecimal": 0x41,
    "kVK_ANSI_KeypadMultiply": 0x43,
    "kVK_ANSI_KeypadPlus": 0x45,
    "kVK_ANSI_KeypadClear": 0x47,
    "kVK_ANSI_KeypadDivide": 0x4B,
    "kVK_ANSI_KeypadEnter": 0x4C,
    "kVK_ANSI_KeypadMinus": 0x4E,
    "kVK_ANSI_KeypadEquals": 0x51,
    "kVK_ANSI_Keypad0": 0x52,
    "kVK_ANSI_Keypad1": 0x53,
    "kVK_ANSI_Keypad2": 0x54,
    "kVK_ANSI_Keypad3": 0x55,
    "kVK_ANSI_Keypad4": 0x56,
    "kVK_ANSI_Keypad5": 0x57,
    "kVK_ANSI_Keypad6": 0x58,
    "kVK_ANSI_Keypad7": 0x59,
    "kVK_ANSI_Keypad8": 0x5B,
    "kVK_ANSI_Keypad9": 0x5C,
    "kVK_Return": 0x24,
    "kVK_Tab": 0x30,
    "kVK_Space": 0x31,
    "kVK_Delete": 0x33,
    "kVK_Escape": 0x35,
    "kVK_Command": 0x37,
    "kVK_Shift": 0x38,
    "kVK_CapsLock": 0x39,
    "kVK_Option": 0x3A,
    "kVK_Control": 0x3B,
    "kVK_RightShift": 0x3C,
    "kVK_RightOption": 0x3D,
    "kVK_RightControl": 0x3E,
    "kVK_Function": 0x3F,
    "kVK_F17": 0x40,
    "kVK_VolumeUp": 0x48,
    "kVK_VolumeDown": 0x49,
    "kVK_Mute": 0x4A,
    "kVK_F18": 0x4F,
    "kVK_F19": 0x50,
    "kVK_F20": 0x5A,
    "kVK_F5": 0x60,
    "kVK_F6": 0x61,
    "kVK_F7": 0x62,
    "kVK_F3": 0x63,
    "kVK_F8": 0x64,
    "kVK_F9": 0x65,
    "kVK_F11": 0x67,
    "kVK_F13": 0x69,
    "kVK_F16": 0x6A,
    "kVK_F14": 0x6B,
    "kVK_F10": 0x6D,
    "kVK_F12": 0x6F,
    "kVK_F15": 0x71,
    "kVK_Help": 0x72,
    "kVK_Home": 0x73,
    "kVK_PageUp": 0x74,
    "kVK_ForwardDelete": 0x75,
    "kVK_F4": 0x76,
    "kVK_End": 0x77,
    "kVK_F2": 0x78,
    "kVK_PageDown": 0x79,
    "kVK_F1": 0x7A,
    "kVK_LeftArrow": 0x7B,
    "kVK_RightArrow": 0x7C,
    "kVK_DownArrow": 0x7D,
    "kVK_UpArrow": 0x7E,
}

quartz_name_by_vk = {y: x for x, y in vk_by_quartz_name.items()}



NATIVE_KEY_CODES = {
    "a": 0x00,
    "s": 0x01,
    "d": 0x02,
    "f": 0x03,
    "h": 0x04,
    "g": 0x05,
    "z": 0x06,
    "x": 0x07,
    "c": 0x08,
    "v": 0x09,
    "b": 0x0B,
    "q": 0x0C,
    "w": 0x0D,
    "e": 0x0E,
    "r": 0x0F,
    "y": 0x10,
    "t": 0x11,
    "number_1": 0x12,
    "number_2": 0x13,
    "number_3": 0x14,
    "number_4": 0x15,
    "number_6": 0x16,
    "number_5": 0x17,
    "equal": 0x18,
    "number_9": 0x19,
    "number_7": 0x1A,
    "dash": 0x1B,
    "number_8": 0x1C,
    "number_0": 0x1D,
    "right_square": 0x1E,
    "o": 0x1F,
    "u": 0x20,
    "left_square": 0x21,
    "i": 0x22,
    "p": 0x23,
    "enter": 0x24,
    "l": 0x25,
    "j": 0x26,
    "apostrophe": 0x27,
    "k": 0x28,
    "semicolon": 0x29,
    "backslash": 0x2A,
    "comma": 0x2B,
    "slash": 0x2C,
    "n": 0x2D,
    "m": 0x2E,
    "dot": 0x2F,
    "tab": 0x30,
    "space": 0x31,
    "grave": 0x32,
    "backspace": 0x33,
    "escape": 0x35,
    "right_command": 0x36,
    "command": 0x37,
    "shift": 0x38,
    "caps_lock": 0x39,
    "option": 0x3A,
    "control": 0x3B,
    "right_shift": 0x3C,
    "right_option": 0x3D,
    "right_control": 0x3E,
    "f17": 0x40,
    "f18": 0x4F,
    "f19": 0x50,
    "f20": 0x5A,
    "f5": 0x60,
    "f6": 0x61,
    "f7": 0x62,
    "f3": 0x63,
    "f8": 0x64,
    "f9": 0x65,
    "f11": 0x67,
    "f13": 0x69,
    "f16": 0x6A,
    "f14": 0x6B,
    "f10": 0x6D,
    "f12": 0x6F,
    "f15": 0x71,
    "home": 0x73,
    "page_up": 0x74,
    "delete": 0x75,
    "f4": 0x76,
    "end": 0x77,
    "f2": 0x78,
    "page_down": 0x79,
    "f1": 0x7A,
    "left": 0x7B,
    "right": 0x7C,
    "down": 0x7D,
    "up": 0x7E,
}

KEY_BY_NATIVE_KEY_CODE = {
    code: key for key, code in NATIVE_KEY_CODES.items()
}


A = {
    "kVK_ANSI_A": "a",
    "kVK_ANSI_S": "s",
    "kVK_ANSI_D": "d",
    "kVK_ANSI_F": "f",
    "kVK_ANSI_H": "h",
    "kVK_ANSI_G": "g",
    "kVK_ANSI_Z": "z",
    "kVK_ANSI_X": "x",
    "kVK_ANSI_C": "c",
    "kVK_ANSI_V": "v",
    "kVK_ANSI_B": "b",
    "kVK_ANSI_Q": "q",
    "kVK_ANSI_W": "w",
    "kVK_ANSI_E": "e",
    "kVK_ANSI_R": "r",
    "kVK_ANSI_Y": "y",
    "kVK_ANSI_T": "t",
    "kVK_ANSI_1": "number_1",
    "kVK_ANSI_2": "number_2",
    "kVK_ANSI_3": "number_3",
    "kVK_ANSI_4": "number_4",
    "kVK_ANSI_6": "number_6",
    "kVK_ANSI_5": "number_5",
    "kVK_ANSI_Equal": "equal",
    "kVK_ANSI_9": "number_9",
    "kVK_ANSI_7": "number_7",
    "kVK_ANSI_Minus": "dash",
    "kVK_ANSI_8": "number_8",
    "kVK_ANSI_0": "number_0",
    "kVK_ANSI_RightBracket": "right_square",
    "kVK_ANSI_O": "o",
    "kVK_ANSI_U": "u",
    "kVK_ANSI_LeftBracket": "left_square",
    "kVK_ANSI_I": "i",
    "kVK_ANSI_P": "p",
    "kVK_ANSI_L": "l",
    "kVK_ANSI_J": "j",
    "kVK_ANSI_Quote": "apostrophe",
    "kVK_ANSI_K": "k",
    "kVK_ANSI_Semicolon": "semicolon",
    "kVK_ANSI_Backslash": "backslash",
    "kVK_ANSI_Comma": "comma",
    "kVK_ANSI_Slash": "slash",
    "kVK_ANSI_N": "n",
    "kVK_ANSI_M": "m",
    "kVK_ANSI_Period": "dot",
    "kVK_ANSI_Grave": "grave",
    "kVK_ANSI_KeypadDecimal": "keypad_dot",
    "kVK_ANSI_KeypadMultiply": "keypad_asterisk",
    "kVK_ANSI_KeypadPlus": "keypad_plus",
    "kVK_ANSI_KeypadClear": "keypad_clear",
    "kVK_ANSI_KeypadDivide": "keypad_slash",
    "kVK_ANSI_KeypadEnter": "keypad_enter",
    "kVK_ANSI_KeypadMinus": "keypad_minus",
    "kVK_ANSI_KeypadEquals": "keypad_equal",
    "kVK_ANSI_Keypad0": "keypad_0",
    "kVK_ANSI_Keypad1": "keypad_1",
    "kVK_ANSI_Keypad2": "keypad_2",
    "kVK_ANSI_Keypad3": "keypad_3",
    "kVK_ANSI_Keypad4": "keypad_4",
    "kVK_ANSI_Keypad5": "keypad_5",
    "kVK_ANSI_Keypad6": "keypad_6",
    "kVK_ANSI_Keypad7": "keypad_7",
    "kVK_ANSI_Keypad8": "keypad_8",
    "kVK_ANSI_Keypad9": "keypad_9",
    "kVK_Return": "enter",
    "kVK_Tab": "tab",
    "kVK_Space": "space",
    "kVK_Delete": "backspace",
    "kVK_Escape": "escape",
    "kVK_Command": "command",
    "kVK_Shift": "shift",
    "kVK_CapsLock": "caps_lock",
    "kVK_Option": "option",
    "kVK_Control": "control",
    "kVK_RightShift": "right_shift",
    "kVK_RightOption": "right_option",
    "kVK_RightControl": "right_control",
    "kVK_F17": "f17",
    "kVK_VolumeUp": "volume_up",
    "kVK_VolumeDown": "volume_down",
    "kVK_Mute": "mute",
    "kVK_F18": "f18",
    "kVK_F19": "f19",
    "kVK_F20": "f20",
    "kVK_F5": "f5",
    "kVK_F6": "f6",
    "kVK_F7": "f7",
    "kVK_F3": "f3",
    "kVK_F8": "f8",
    "kVK_F9": "f9",
    "kVK_F11": "f11",
    "kVK_F13": "f13",
    "kVK_F16": "f16",
    "kVK_F14": "f14",
    "kVK_F10": "f10",
    "kVK_F12": "f12",
    "kVK_F15": "f15",
    "kVK_Help": "help",
    "kVK_Home": "home",
    "kVK_PageUp": "page_up",
    "kVK_ForwardDelete": "delete",
    "kVK_F4": "f4",
    "kVK_End": "end",
    "kVK_F2": "f2",
    "kVK_PageDown": "page_down",
    "kVK_F1": "f1",
    "kVK_LeftArrow": "left",
    "kVK_RightArrow": "right",
    "kVK_DownArrow": "down",
    "kVK_UpArrow": "up",
}

_ = {k: quartz_name_by_vk.get(c, f'unknown: {c}') for k, c in NATIVE_KEY_CODES.items()}, {x: KEY_BY_NATIVE_KEY_CODE.get(c, f'unknown: {c}') for x, c in vk_by_quartz_name.items()}

_ = { f'Quartz.{x}': KEY_BY_NATIVE_KEY_CODE.get(c, f'quartz {x}')  for x, c in vk_by_quartz_name.items() }

{y: vk_by_quartz_name[x] for x, y in A.items()}
# Out:
# {'a': 0,
#  's': 1,
#  'd': 2,
#  'f': 3,
#  'h': 4,
#  'g': 5,
#  'z': 6,
#  'x': 7,
#  'c': 8,
#  'v': 9,
#  'b': 11,
#  'q': 12,
#  'w': 13,
#  'e': 14,
#  'r': 15,
#  'y': 16,
#  't': 17,
#  'number_1': 18,
#  'number_2': 19,
#  'number_3': 20,
#  'number_4': 21,
#  'number_6': 22,
#  'number_5': 23,
#  'equal': 24,
#  'number_9': 25,
#  'number_7': 26,
#  'dash': 27,
#  'number_8': 28,
#  'number_0': 29,
#  'right_square': 30,
#  'o': 31,
#  'u': 32,
#  'left_square': 33,
#  'i': 34,
#  'p': 35,
#  'l': 37,
#  'j': 38,
#  'apostrophe': 39,
#  'k': 40,
#  'semicolon': 41,
#  'backslash': 42,
#  'comma': 43,
#  'slash': 44,
#  'n': 45,
#  'm': 46,
#  'dot': 47,
#  'grave': 50,
#  'keypad_dot': 65,
#  'keypad_asterisk': 67,
#  'keypad_plus': 69,
#  'keypad_clear': 71,
#  'keypad_slash': 75,
#  'keypad_enter': 76,
#  'keypad_minus': 78,
#  'keypad_equal': 81,
#  'keypad_0': 82,
#  'keypad_1': 83,
#  'keypad_2': 84,
#  'keypad_3': 85,
#  'keypad_4': 86,
#  'keypad_5': 87,
#  'keypad_6': 88,
#  'keypad_7': 89,
#  'keypad_8': 91,
#  'keypad_9': 92,
#  'enter': 36,
#  'tab': 48,
#  'space': 49,
#  'backspace': 51,
#  'escape': 53,
#  'command': 55,
#  'shift': 56,
#  'caps_lock': 57,
#  'option': 58,
#  'control': 59,
#  'right_shift': 60,
#  'right_option': 61,
#  'right_control': 62,
#  'f17': 64,
#  'volume_up': 72,
#  'volume_down': 73,
#  'mute': 74,
#  'f18': 79,
#  'f19': 80,
#  'f20': 90,
#  'f5': 96,
#  'f6': 97,
#  'f7': 98,
#  'f3': 99,
#  'f8': 100,
#  'f9': 101,
#  'f11': 103,
#  'f13': 105,
#  'f16': 106,
#  'f14': 107,
#  'f10': 109,
#  'f12': 111,
#  'f15': 113,
#  'help': 114,
#  'home': 115,
#  'page_up': 116,
#  'delete': 117,
#  'f4': 118,
#  'end': 119,
#  'f2': 120,
#  'page_down': 121,
#  'f1': 122,
#  'left': 123,
#  'right': 124,
#  'down': 125,
#  'up': 126}

# %%
# Generate a dict of event type integer values mapped to the corresponding constant names

# Names and values of event type constants scraped from https://developer.apple.com/documentation/appkit/nseventtype?language=objc
s = """
Getting Mouse-Related Event Types
NSEventTypeLeftMouseDown
The user pressed the left mouse button.
NSEventTypeLeftMouseDragged
The user moved the mouse while holding down the left mouse button.
NSEventTypeLeftMouseUp
The user released the left mouse button.
NSEventTypeRightMouseDown
The user pressed the right mouse button.
NSEventTypeRightMouseUp
The user released the right mouse button.
NSEventTypeRightMouseDragged
The user moved the mouse while holding down the right mouse button.
NSEventTypeOtherMouseDown
The user pressed a tertiary mouse button.
NSEventTypeOtherMouseDragged
The user moved the mouse while holding down a tertiary mouse button.
NSEventTypeOtherMouseUp
The user released a tertiary mouse button.
NSEventTypeMouseMoved
The user moved the mouse in a way that caused the cursor to move onscreen.
NSEventTypeMouseEntered
The cursor entered a well-defined area, such as a view.
NSEventTypeMouseExited
The cursor exited a well-defined area, such as a view.
Getting Keyboard Event Types
NSEventTypeKeyDown
The user pressed a key on the keyboard.
NSEventTypeKeyUp
The user released a key on the keyboard.
Getting Touch-Based Events
NSEventTypeBeginGesture
An event marking the beginning of a gesture.
NSEventTypeEndGesture
An event that marks the end of a gesture.
NSEventTypeMagnify
The user performed a pinch-open or pinch-close gesture.
NSEventTypeSmartMagnify
The user performed a smart-zoom gesture.
NSEventTypeSwipe
The user performed a swipe gesture.
NSEventTypeRotate
The user performed a rotate gesture.
NSEventTypeGesture
The user performed a nonspecific type of gesture.
NSEventTypeDirectTouch
The user touched a portion of the touch bar.
NSEventTypeTabletPoint
The user touched a point on a tablet.
NSEventTypeTabletProximity
A pointing device is near, but not touching, the associated tablet.
NSEventTypePressure
An event that reports a change in pressure on a pressure-sensitive device.
Getting Other Input Types
NSEventTypeScrollWheel
The scroll wheel position changed.
NSEventTypeChangeMode
The user changed the mode of a connected device.
Getting System Event Types
NSEventTypeAppKitDefined
An AppKit-related event occurred.
NSEventTypeApplicationDefined
An app-defined event occurred.
NSEventTypeCursorUpdate
An event that updates the cursor.
NSEventTypeFlagsChanged
The event flags changed.
NSEventTypePeriodic
An event that provides execution time to periodic tasks.
NSEventTypeQuickLook
An event that initiates a Quick Look request.
NSEventTypeSystemDefined
A system-related event occur
"""

attr_names = []

for line in s.split("\n"):
    line = line.strip()
    if line.startswith("NS"):
        attr_names.append(line)

print(attr_names)

attr_by_value = {Quartz.__getattr__(a): a for a in attr_names}

print(attr_by_value)
# Out:
# ['NSEventTypeLeftMouseDown', 'NSEventTypeLeftMouseDragged', 'NSEventTypeLeftMouseUp', 'NSEventTypeRightMouseDown', 'NSEventTypeRightMouseUp', 'NSEventTypeRightMouseDragged', 'NSEventTypeOtherMouseDown', 'NSEventTypeOtherMouseDragged', 'NSEventTypeOtherMouseUp', 'NSEventTypeMouseMoved', 'NSEventTypeMouseEntered', 'NSEventTypeMouseExited', 'NSEventTypeKeyDown', 'NSEventTypeKeyUp', 'NSEventTypeBeginGesture', 'NSEventTypeEndGesture', 'NSEventTypeMagnify', 'NSEventTypeSmartMagnify', 'NSEventTypeSwipe', 'NSEventTypeRotate', 'NSEventTypeGesture', 'NSEventTypeDirectTouch', 'NSEventTypeTabletPoint', 'NSEventTypeTabletProximity', 'NSEventTypePressure', 'NSEventTypeScrollWheel', 'NSEventTypeChangeMode', 'NSEventTypeAppKitDefined', 'NSEventTypeApplicationDefined', 'NSEventTypeCursorUpdate', 'NSEventTypeFlagsChanged', 'NSEventTypePeriodic', 'NSEventTypeQuickLook', 'NSEventTypeSystemDefined']
# {1: 'NSEventTypeLeftMouseDown', 6: 'NSEventTypeLeftMouseDragged', 2: 'NSEventTypeLeftMouseUp', 3: 'NSEventTypeRightMouseDown', 4: 'NSEventTypeRightMouseUp', 7: 'NSEventTypeRightMouseDragged', 25: 'NSEventTypeOtherMouseDown', 27: 'NSEventTypeOtherMouseDragged', 26: 'NSEventTypeOtherMouseUp', 5: 'NSEventTypeMouseMoved', 8: 'NSEventTypeMouseEntered', 9: 'NSEventTypeMouseExited', 10: 'NSEventTypeKeyDown', 11: 'NSEventTypeKeyUp', 19: 'NSEventTypeBeginGesture', 20: 'NSEventTypeEndGesture', 30: 'NSEventTypeMagnify', 32: 'NSEventTypeSmartMagnify', 31: 'NSEventTypeSwipe', 18: 'NSEventTypeRotate', 29: 'NSEventTypeGesture', 37: 'NSEventTypeDirectTouch', 23: 'NSEventTypeTabletPoint', 24: 'NSEventTypeTabletProximity', 34: 'NSEventTypePressure', 22: 'NSEventTypeScrollWheel', 38: 'NSEventTypeChangeMode', 13: 'NSEventTypeAppKitDefined', 15: 'NSEventTypeApplicationDefined', 17: 'NSEventTypeCursorUpdate', 12: 'NSEventTypeFlagsChanged', 16: 'NSEventTypePeriodic', 33: 'NSEventTypeQuickLook', 14: 'NSEventTypeSystemDefined'}
